# %% [markdown]
# ### Estimate the number of synapses that disappear due to intensity fluctuation

# %% [markdown]
# For each fish of the No Stim Control group separately let's look at the conditional probability to go from Some intensity to the other.

# %%
# %cd ..
# %pwd # wanna be in 'D:\\Code\\repos\\psd95_segmentation'

# %% [markdown]
# #### Have a look at intensity distribution

# %%
# LOAD DATA 
import pickle

stu = pickle.load( open( "data/interim/stu_cohort_EWW.p", "rb" ) )

# %%
from notebooks.synapse_features_nb import plot_histo

plot_histo(stu, 'LR', '1-0CN6')
